# %% [markdown]
# # project: US BikeShare
# ## introduction:
# this project is the bike share data in the United States over the past decade.</br>
# as the bike sharing has been growing in popularity specially in big crowded cities,
# bike sharing is about renting a bike from starting station to another station of your desire.
# </br>
#
# in this data set we have the bike share data for three major cities in the United Sates, Like Chicago, New York and Washington DC</br>
# we have data like start time of the trip, Start and end stations, Duration of the Trip,
# and also gender of the user
#
# </br>
#
# # 1 Popular times of travel
# most common month most common day of week most common hour of day
#
# # 2 Popular stations and trip
# most common start station most common end station most common trip from start to end (i.e., most frequent combination of start station and end station)
#
# # 3 Trip duration
# total travel time average travel time
#
# # 4 User info
# counts of each user type counts of each gender (only available for NYC and Chicago) earliest, most recent, most common year of birth (only available for NYC and Chicago)

# %%
import time
import pandas as pd
import numpy as np

CITY_DATA = {'chicago': 'chicago.csv',
             'new york city': 'new_york_city.csv',
             'washington': 'washington.csv'}

# %%
def get_filters():
    """
    Asks user to specify a city, month, and day to analyze.

    Returns:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    """

    print('Hello! Let\'s explore some US bikeshare data!')
    print("let's apply some filters pick your desired city..")

    # TO DO: get user input for city (chicago, new york city, washington). HINT: Use a while loop to handle invalid
    # inputs
    while True:
        city = input("Which one \nwe have only chicago , new york city and washington available: ").lower()
        if city not in CITY_DATA:
            print("Re-Enter city name please")

        else:
            break

    # TO DO: get user input for month (all, january, february, ... , june)
    while True:
        month = input("pick a month from january to june, type 'all' to display all months ").lower()
        months = ['january', 'february', 'march', 'april', 'may', 'june']

        if month != "all" and month not in months:
            print("Re-Enter the month please")

        else:
            break

    # TO DO: get user input for day of week (all, monday, tuesday, ... sunday)
    while True:
        day = input("pick a day, type 'all' to display all days ").lower()
        days = ['sunday', 'monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday']

        if day != "all" and day not in days:
            print("Re-Enter the day please")

        else:
            break

    print('-' * 40)
    return city, month, day


def load_data(city, month, day):
    """
    Loads data for the specified city and filters by month and day if applicable.

    Args:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    Returns:
        df - Pandas DataFrame containing city data filtered by month and day
    """
    # Loading the City name filter
    df = pd.read_csv(CITY_DATA[city])

    df["Start Time"] = pd.to_datetime(df["Start Time"])
    # Loading Month Filter
    df['month'] = df['Start Time'].dt.month
    # Loading Day Filter
    df['day_of_week'] = df['Start Time'].dt.day_name()

    if month != 'all':
        months = ['january', 'february', 'march', 'april', 'may', 'june']
        month = months.index(month) + 1
        df = df[df['month'] == month]

    if day != 'all':
        df = df[df['day_of_week'] == day.title()]
    return df


def time_stats(df):
    """Displays statistics on the most frequent times of travel."""

    print('\nCalculating The Most Frequent Times of Travel...\n')
    start_time = time.time()

    # TO DO: display the most common month
    commonMonth = df['month'].mode()[0]
    months = ['january', 'february', 'march', 'april', 'may',
              'june']  # Used to take commonMonth as an index for the array to display name of the desired month
    mon = months[commonMonth - 1]
    print("Most Common Month is: ", mon)

    # TO DO: display the most common day of week
    commonDay = df['day_of_week'].mode()[0]
    print("Most Common Day is: ", commonDay)

    # TO DO: display the most common start hour
    df['hour'] = df['Start Time'].dt.hour
    commonHour = df['hour'].mode()[0]
    print("Most Common Hour is: ", commonHour)

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-' * 40)


def station_stats(df):
    """Displays statistics on the most popular stations and trip."""

    print('\nCalculating The Most Popular Stations and Trip...\n')
    start_time = time.time()

    # TO DO: display most commonly used start station
    commonStart = df['Start Station'].mode()[0]
    print("Most Common Start Station is: " + commonStart)

    # TO DO: display most commonly used end station
    commonEnd = df['End Station'].mode()[0]
    print("Most Common End Station is: " + commonEnd)

    # TO DO: display most frequent combination of start station and end station trip
    commonTrip = (df["Start Station"] + " - " + df["End Station"]).mode()[0]
    print("Most Common Trip is: " + commonTrip)

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-' * 40)


def trip_duration_stats(df):
    """Displays statistics on the total and average trip duration."""

    print('\nCalculating Trip Duration...\n')
    start_time = time.time()

    # TO DO: display total travel time
    totalTime = df["Trip Duration"].sum()
    print("Total Trip Duration is ", totalTime / 3600, " hours")

    # TO DO: display mean travel time
    meanTime = df["Trip Duration"].mean()
    print("Mean Trip Duration is ", meanTime / 3600, " hours")

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-' * 40)


def user_stats(df):
    """Displays statistics on bikeshare users."""

    print('\nCalculating User Stats...\n')
    start_time = time.time()

    # TO DO: Display counts of user types
    print("Number of User Types:\n", df["User Type"].value_counts())

    # TO DO: Display counts of gender
    if 'Gender' in df:
        print("count of Gender is:\n", df["Gender"].value_counts())

    # TO DO: Display earliest, most recent, and most common year of birth
    if 'Birth Year' in df:
        earliest = int(df["Birth Year"].min())
        print("Earliest Birth Year is:", earliest)
        Recent = int(df["Birth Year"].max())
        print("Most Recent Birth Year is:", Recent)
        common = int(df["Birth Year"].mode()[0])
        print("Most Common Birth Year is:", common)

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-' * 40)


def display_data(df):
    choice = input("Would you like to view 5 rows of individual trip data? Enter yes or no?\n").lower()
    i=0
    while True:
        if choice=="no":
            break
        else:
            print(df[i:i+5])
            choice = input("Would you like to view 5 rows of individual trip data? Enter yes or no?\n").lower()
            i=i+5

# %%
def main():
    while True:
        city, month, day = get_filters()
        df = load_data(city, month, day)
        display_data(df)
        time_stats(df)
        station_stats(df)
        trip_duration_stats(df)
        user_stats(df)

        restart = input('\nWould you like to restart? Enter yes or no.\n')
        if restart.lower() != 'yes':
            break


if __name__ == "__main__":
    main()
# Out:
# Hello! Let's explore some US bikeshare data!
# let's apply some filters pick your desired city..
# Which one
# we have only chicago , new york city and washington available: chicago
# pick a month from january to june, type 'all' to display all months may
# pick a day, type 'all' to display all days all
# ----------------------------------------
# Would you like to view 5 rows of individual trip data? Enter yes or no?
# yes
#     Unnamed: 0          Start Time             End Time  Trip Duration  \
# 1       955915 2017-05-25 18:19:03  2017-05-25 18:45:53           1610
# 6       961916 2017-05-26 09:41:44  2017-05-26 09:46:25            281
# 13     1023296 2017-05-30 15:46:18  2017-05-30 15:52:12            354
# 15      958716 2017-05-25 22:59:33  2017-05-25 23:07:19            466
# 16      718598 2017-05-03 13:20:38  2017-05-03 13:31:13            635
#
#                  Start Station                     End Station   User Type  \
# ...

# %% [markdown]
# # Conclusion:
# as we see in the previous example we used Chicago city as an example,
# and as we see from the data we have that a lot of people are really considering the Bike Sharing idea lately as we have in chicago only more than 51000 subscriber
# and almost 16000 customer.</br>
# and as we can see we have users born in 2016 who are using the bike sharing system.
# ### Limitation:
#   sadly the data we have is only for three states only as this was the only data provided by the course.
